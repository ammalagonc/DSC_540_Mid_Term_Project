# %% [markdown]
# # DSC 540 - Data Preparation
# # Bellevue University

# %% [markdown]
# ## Mid-Term Project - Food Access Research Atlas
# ### Ambrose M Malagon Cordero

# %% [markdown]
# The data set chosen for this Mid-Term Project is the Food Access Research Atlas Data Download from the United States Deparment of Agriculture (https://www.ers.usda.gov/data-products/food-access-research-atlas/download-the-data/). The data is an Excel File that contains 3 tabs:
#
# * Read Me - A description of the file contents.
# * Variable Look-Up: Translation table of the field names in the Data Table with the long name and the description of the field.
# * Food Access Research Atlas: The Data Table: Consists of 147 variables with 72,864.

# %% [markdown]
# --------------------

# %% [markdown]
# #### Step 1: Importing the Data
#
# We start by importing the _xlrd_ module, since we are handling an Excel File.

# %%
import xlrd

# %% [markdown]
# We open the file and override the encoding in case there are characters that are not UTF-8 compatible.

# %%
wb = xlrd.open_workbook("DataDownload2015.xlsx",encoding_override="cp1252")

# %% [markdown]
# Next - We import the sheets we need by their index value: Variable Look-Up (1) and Food Access Research Atlas (2).

# %%
sheet1 = wb.sheet_by_index(1)
sheet2 = wb.sheet_by_index(2)

# %% [markdown]
# #### Requirement I - Replace headers

# %% [markdown]
# For this task, we are going to create some custom functions:

# %%
def header_translation(sheet):
    '''
    Takes the converted Excel sheet data and returns a data dictionary with the field name and their respective descriptions. 
    '''
    data_dict = {}
    for i in range(1,sheet.nrows):
        count = i-1
        data = sheet.row_values(i)
        data_dict[count] = data
    return data_dict

# %%
# Run the header_translations function and assign the resulting dictionary to the headers_dict variable.
headers_dict = header_translation(sheet1)

# %%
def list_data(sheet):
    '''
    Takes the converted Excel sheet data and returns a list of lists of said data.
    '''
    data = list()
    for i in range(sheet.nrows):
        data.append(sheet.row_values(i))
    return data

# %%
# Run the list_data function and assign the resulting list to the FARA variable.
FARA = list_data(sheet2)

# %%
def list_to_dict(data, header):
    '''
    Return a dictionary of dictionaries, constructed from the file data using the list of lists data and the translated header data. 
    We declare an empty dictionary and iterate over the length of the data row starting from 1; We do this because
    the first value is a sequential unassigned number (we will use this as our prime dictionary key). We declate another empty 
    dictionary inside the for loop, assign a expression generator to create a dictionary using the file and header data and then
    append this to the main dictionary. The second dictionary is wiped clean with each new iteration.
    '''
    res_dict = {}
    for i in range(len(data)):
        append_dict = {}
        append_dict = {header[j][2]: data[i][j] for j in range(len(header))} 
        res_dict[i] = append_dict
    return res_dict

# %%
# Run the list_to_dict function and assign the resulting list to the results variable.
results = list_to_dict(FARA[1:],headers_dict)

# %%
# Print the first value of the results dictionary.
results[0]
# Out:
# {'Census tract number': '01001020100',
#  'State name': 'Alabama',
#  'County name': 'Autauga',
#  'Flag for urban tract': 1.0,
#  'Population count from 2010 census': 1912.0,
#  'Occupied housing unit count from 2010 census': 693.0,
#  'Flag for tract where >=67%': 0.0,
#  'Count of tract population residing in group quarters': 0.0,
#  'Percent of tract population residing in group quarters': 0.0,
#  'Flag for food desert when considering low accessibilty at 1 and 10 miles': 0.0,
#  'Flag for food desert when considering low accessibilty at 1/2 and 10 miles': 0.0,
#  'Flag for food desert when considering low accessibilty at 1 and 20 miles': 0.0,
#  'Flag for food desert when considering vehicle access or at 20 miles': 0.0,
#  'Flag for tract where >= 100 of households do not have a vehicle, and beyond 1/2 mile from supermarket': 0.0,
#  'Flag for low income tract': 0.0,
#  'Share of the tract population living with income at or below the Federal poverty thresholds for family size': 10.0,
#  'Tract median family income': 74750.0,
#  'Flag for low access tract at 1 mile for urban areas or 10 miles for rural areas': 1.0,
#  'Flag for low access tract at 1/2 mile for urban areas or 10 miles for rural areas': 1.0,
#  'Flag for low access tract at 1 mile for urban areas or 20 miles for rural areas': 1.0,
#  'Flag for low access tract when considering 1/2 mile distance': 1.0,
#  'Flag for low access tract when considering 1 mile distance': 1.0,
#  'Flag for low access tract when considering 10 mile distance': 0.0,
#  'Flag for low access tract when considering 20 mile distance': 0.0,
#  'Flag for tract where >= 100 of households do not have a vehicle, and beyond 1/2 mile from supermarket; or >= 500 individuals are beyond 20 miles from supermarket ; or >= 33% of individuals are beyond 20 miles from supermarket': 0.0,
#  'Population count beyond 1 mile for urban areas or 10 miles for rural areas from supermarket': 1357.48093973123,
#  'Population count beyond 1/2 mile for urban areas or 10 miles for rural areas from supermarket': 1732.22546793776,
#  'Population count beyond 1 mile for urban areas or 20 miles for rural areas from supermarket': 1357.48093973123,
#  'Low income population count beyond 1 mile for urban areas or 10 miles for rural areas from supermarket': 322.084611989615,
#  'Low income population count beyond 1/2 mile for urban areas or 10 miles for rural areas from supermarket': 411.69075440563,
#  'Low income population count beyond 1 mile for urban areas or 20 miles for rural areas from supermarket': 322.084611989615,
#  'Population count beyond 1/2 mile from supermarket': 1732.22546793776,
#  'Share of tract population that are beyond 1/2 mile from supermarket': 0.905975663147367,
#  'Low income population count beyond 1/2 mile from supermarket': 411.69075440563,
#  'Share of tract population that are low income individuals beyond 1/2 mile from supermarket': 0.215319432220518,
#  'Kids population count beyond 1/2 mile from supermarket': 466.426429549697,
#  'Share of tract population that are kids beyond 1/2 mile from supermarket': 0.243946877379549,
#  'Seniors population count beyond 1/2 mile from supermarket': 198.82822029374,
#  'Share of tract population that are seniors beyond 1/2 mile from supermarket': 0.103989654965346,
#  'White population count beyond 1/2 mile from supermarket': 1482.88141720404,
#  'Share of tract population that are white beyond 1/2 mile from supermarket': 0.77556559477199,
#  'Black or African American population count beyond 1/2 mile from supermarket': 184.319105652335,
#  'Share of tract population that are Black or African American beyond 1/2 mile from supermarket': 0.096401205885113,
#  'Asian population count beyond 1/2 mile from supermarket': 12.7181206382992,
#  'Share of tract population that are Asian beyond 1/2 mile from supermarket': 0.006651736735512,
#  'Native Hawaiian or Other Pacific Islander population count beyond 1/2 mile from supermarket': 0.0,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 1/2 mile from supermarket': 0.0,
#  'American Indian or Alaska Native population count beyond 1/2 mile from supermarket': 13.9699329382456,
#  'Share of tract population that are American Indian or Alaska Native beyond 1/2 mile from supermarket': 0.007306450281509,
#  'Other/Multiple race population count beyond 1/2 mile from supermarket': 38.3368966744164,
#  'Share of tract population that are Other/Multiple race beyond 1/2 mile from supermarket': 0.020050678176996,
#  'Hispanic or Latino ethnicity population count beyond 1/2 mile from supermarket': 39.6950211152579,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 1/2 mile from supermarket': 0.020760994307143,
#  'Housing units without vehicle count beyond 1/2 mile from supermarket': 21.5562475419237,
#  'Share of tract housing units that are without vehicle and beyond 1/2 mile from supermarket': 0.031105696308692,
#  'Housing units receiving SNAP benefits count beyond 1/2 mile from supermarket': 101.87739790781,
#  'Share of tract housing units receiving SNAP benefits count beyond 1/2 mile from supermarket': 0.147009232190203,
#  'Population count beyond 1 mile from supermarket': 1357.48093973123,
#  'Share of tract population that are beyond 1 mile from supermarket': 0.709979570989139,
#  'Low income population count beyond 1 mile from supermarket': 322.084611989615,
#  'Share of tract population that are low income individuals beyond 1 mile from supermarket': 0.168454294973649,
#  'Kids population count beyond 1 mile from supermarket': 363.63838111062,
#  'Share of tract population that are kids beyond 1 mile from supermarket': 0.190187437819362,
#  'Seniors population count beyond 1 mile from supermarket': 162.497245970298,
#  'Share of tract population that are seniors beyond 1 mile from supermarket': 0.084988099356851,
#  'White population count beyond 1 mile from supermarket': 1161.80255254392,
#  'Share of tract population that are white beyond 1 mile from supermarket': 0.607637318276114,
#  'Black or African American population count beyond 1 mile from supermarket': 147.487665743276,
#  'Share of tract population that are Black or African American beyond 1 mile from supermarket': 0.077137900493345,
#  'Asian population count beyond 1 mile from supermarket': 11.015106447583,
#  'Share of tract population that are Asian beyond 1 mile from supermarket': 0.00576103893702,
#  'Native Hawaiian or Other Pacific Islander population count beyond 1 mile from supermarket': 0.0,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 1 mile from supermarket': 0.0,
#  'American Indian or Alaska Native population count beyond 1 mile from supermarket': 9.99659218850501,
#  'Share of tract population that are American Indian or Alaska Native beyond 1 mile from supermarket': 0.005228343194825,
#  'Other/Multiple race population count beyond 1 mile from supermarket': 27.1790304430178,
#  'Share of tract population that are Other/Multiple race beyond 1 mile from supermarket': 0.014214974081076,
#  'Hispanic or Latino ethnicity population count beyond 1 mile from supermarket': 29.7155356679722,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 1 mile from supermarket': 0.015541598152705,
#  'Housing units without vehicle count beyond 1 mile from supermarket': 9.77285467438832,
#  'Share of tract housing units that are without vehicle and beyond 1 mile from supermarket': 0.014102243397386,
#  'Housing units receiving SNAP benefits count beyond 1 mile from supermarket': 79.5468434111098,
#  'Share of tract housing units receiving SNAP benefits count beyond 1 mile from supermarket': 0.114786209828441,
#  'Population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are beyond 10 miles from supermarket': 0.0,
#  'Low income population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are low income individuals beyond 10 miles from supermarket': 0.0,
#  'Kids population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are kids beyond 10 miles from supermarket': 0.0,
#  'Seniors population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are seniors beyond 10 miles from supermarket': 0.0,
#  'White population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are white beyond 10 miles from supermarket': 0.0,
#  'Black or African American population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are Black or African American beyond 10 miles from supermarket': 0.0,
#  'Asian population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are Asian beyond 10 miles from supermarket': 0.0,
#  'Native Hawaiian or Other Pacific Islander population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 10 miles from supermarket': 0.0,
#  'American Indian or Alaska Native population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are American Indian or Alaska Native beyond 10 miles from supermarket': 0.0,
#  'Other/Multiple race population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are Other/Multiple race beyond 10 miles from supermarket': 0.0,
#  'Hispanic or Latino ethnicity population count beyond 10 miles from supermarket': 0.0,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 10 miles from supermarket': 0.0,
#  'Housing units without vehicle count beyond 10 miles from supermarket': 0.0,
#  'Share of tract housing units that are without vehicle and beyond 10 miles from supermarket': 0.0,
#  'Housing units receiving SNAP benefits count beyond 10 miles from supermarket': 0.0,
#  'Share of tract housing units receiving SNAP benefits count beyond 10 miles from supermarket': 0.0,
#  'Population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are beyond 20 miles from supermarket': 0.0,
#  'Low income population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are low income individuals beyond 20 miles from supermarket': 0.0,
#  'Kids population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are kids beyond 20 miles from supermarket': 0.0,
#  'Seniors population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are seniors beyond 20 miles from supermarket': 0.0,
#  'White population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are white beyond 20 miles from supermarket': 0.0,
#  'Black or African American population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are Black or African American beyond 20 miles from supermarket': 0.0,
#  'Asian population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are Asian beyond 20 miles from supermarket': 0.0,
#  'Native Hawaiian or Other Pacific Islander population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 20 miles from supermarket': 0.0,
#  'American Indian or Alaska Native population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are American Indian or Alaska Native beyond 20 miles from supermarket': 0.0,
#  'Other/Multiple race population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are Other/Multiple race beyond 20 miles from supermarket': 0.0,
#  'Hispanic or Latino ethnicity population count beyond 20 miles from supermarket': 0.0,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 20 miles from supermarket': 0.0,
#  'Housing units without vehicle count beyond 20 miles from supermarket': 0.0,
#  'Share of tract housing units that are without vehicle and beyond 20 miles from supermarket': 0.0,
#  'Housing units receiving SNAP benefits count beyond 20 miles from supermarket': 0.0,
#  'Share of tract housing units receiving SNAP benefits count beyond 20 miles from supermarket': 0.0,
#  'Total count of low-income population in tract ': 448.0,
#  'Total count of children age 0-17 in tract ': 507.0,
#  'Total count of seniors age 65+ in tract ': 221.0,
#  'Total count of White population in tract ': 1622.0,
#  'Total count of Black or African American population in tract ': 217.0,
#  'Total count of Asian population in tract ': 14.0,
#  'Total count of Native Hawaiian and Other Pacific Islander population in tract ': 0.0,
#  'Total count of American Indian and Alaska Native population in tract ': 14.0,
#  'Total count of Other/Multiple race population in tract ': 45.0,
#  'Total count of Hispanic or Latino population in tract ': 44.0,
#  'Total count of housing units without a vehicle in tract ': 26.0,
#  'Total count of housing units receiving SNAP benefits in tract ': 112.0}

# %% [markdown]
# -------------------------------

# %% [markdown]
# #### Requirement II - Format Data to a Readable Format

# %% [markdown]
# For this section, we use string formating and a for loop to iterate over the values of the first field.

# %%
for i in results[1]:
    print(f'Field: {i}\nValue: {results[1][i]}\n')
# Out:
# Field: Census tract number
# Value: 01001020200
#
# Field: State name
# Value: Alabama
#
# Field: County name
# Value: Autauga
#
# Field: Flag for urban tract
# Value: 1.0
#
# Field: Population count from 2010 census
# Value: 2170.0
#
# Field: Occupied housing unit count from 2010 census
# Value: 743.0
#
# Field: Flag for tract where >=67%
# Value: 0.0
#
# Field: Count of tract population residing in group quarters
# Value: 181.0
#
# Field: Percent of tract population residing in group quarters
# Value: 0.0834101
#
# Field: Flag for food desert when considering low accessibilty at 1 and 10 miles
# Value: 0.0
#
# Field: Flag for food desert when considering low accessibilty at 1/2 and 10 miles
# Value: 0.0
#
# Field: Flag for food desert when considering low accessibilty at 1 and 20 miles
# Value: 0.0
#
# Field: Flag for food desert when considering vehicle access or at 20 miles
# Value: 0.0
#
# Field: Flag for tract where >= 100 of households do not have a vehicle, and beyond 1/2 mile from supermarket
# Value: 0.0
#
# Field: Flag for low income tract
# Value: 0.0
#
# Field: Share of the tract population living with income at or below the Federal poverty thresholds for family size
# Value: 18.1999999999999
#
# Field: Tract median family income
# Value: 51875.0
#
# Field: Flag for low access tract at 1 mile for urban areas or 10 miles for rural areas
# Value: 0.0
#
# Field: Flag for low access tract at 1/2 mile for urban areas or 10 miles for rural areas
# Value: 1.0
#
# Field: Flag for low access tract at 1 mile for urban areas or 20 miles for rural areas
# Value: 0.0
#
# Field: Flag for low access tract when considering 1/2 mile distance
# Value: 1.0
#
# Field: Flag for low access tract when considering 1 mile distance
# Value: 0.0
#
# Field: Flag for low access tract when considering 10 mile distance
# Value: 0.0
#
# Field: Flag for low access tract when considering 20 mile distance
# Value: 0.0
#
# Field: Flag for tract where >= 100 of households do not have a vehicle, and beyond 1/2 mile from supermarket; or >= 500 individuals are beyond 20 miles from supermarket ; or >= 33% of individuals are beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Population count beyond 1 mile for urban areas or 10 miles for rural areas from supermarket
# Value: 483.429682502523
#
# Field: Population count beyond 1/2 mile for urban areas or 10 miles for rural areas from supermarket
# Value: 1410.37482770578
#
# Field: Population count beyond 1 mile for urban areas or 20 miles for rural areas from supermarket
# Value: 483.429682502523
#
# Field: Low income population count beyond 1 mile for urban areas or 10 miles for rural areas from supermarket
# Value: 145.14141792804
#
# Field: Low income population count beyond 1/2 mile for urban areas or 10 miles for rural areas from supermarket
# Value: 475.306031379848
#
# Field: Low income population count beyond 1 mile for urban areas or 20 miles for rural areas from supermarket
# Value: 145.14141792804
#
# Field: Population count beyond 1/2 mile from supermarket
# Value: 1410.37482770578
#
# Field: Share of tract population that are beyond 1/2 mile from supermarket
# Value: 0.64994231691511
#
# Field: Low income population count beyond 1/2 mile from supermarket
# Value: 475.306031379848
#
# Field: Share of tract population that are low income individuals beyond 1/2 mile from supermarket
# Value: 0.219035037502234
#
# Field: Kids population count beyond 1/2 mile from supermarket
# Value: 448.163511756807
#
# Field: Share of tract population that are kids beyond 1/2 mile from supermarket
# Value: 0.206526963943229
#
# Field: Seniors population count beyond 1/2 mile from supermarket
# Value: 139.30539013847
#
# Field: Share of tract population that are seniors beyond 1/2 mile from supermarket
# Value: 0.064196032321876
#
# Field: White population count beyond 1/2 mile from supermarket
# Value: 412.291348965605
#
# Field: Share of tract population that are white beyond 1/2 mile from supermarket
# Value: 0.189996013348205
#
# Field: Black or African American population count beyond 1/2 mile from supermarket
# Value: 945.317795821814
#
# Field: Share of tract population that are Black or African American beyond 1/2 mile from supermarket
# Value: 0.435630320655214
#
# Field: Asian population count beyond 1/2 mile from supermarket
# Value: 4.00000012698183
#
# Field: Share of tract population that are Asian beyond 1/2 mile from supermarket
# Value: 0.001843318030867
#
# Field: Native Hawaiian or Other Pacific Islander population count beyond 1/2 mile from supermarket
# Value: 0.0
#
# Field: Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 1/2 mile from supermarket
# Value: 0.0
#
# Field: American Indian or Alaska Native population count beyond 1/2 mile from supermarket
# Value: 4.71758192859852
#
# Field: Share of tract population that are American Indian or Alaska Native beyond 1/2 mile from supermarket
# Value: 0.002174000888755
#
# Field: Other/Multiple race population count beyond 1/2 mile from supermarket
# Value: 44.0481012072123
#
# Field: Share of tract population that are Other/Multiple race beyond 1/2 mile from supermarket
# Value: 0.020298664150789
#
# Field: Hispanic or Latino ethnicity population count beyond 1/2 mile from supermarket
# Value: 34.587909407739
#
# Field: Share of tract population that are of Hispanic or Latino ethnicity beyond 1/2 mile from supermarket
# Value: 0.015939128759327
#
# Field: Housing units without vehicle count beyond 1/2 mile from supermarket
# Value: 58.628965407639
#
# Field: Share of tract housing units that are without vehicle and beyond 1/2 mile from supermarket
# Value: 0.078908432580941
#
# Field: Housing units receiving SNAP benefits count beyond 1/2 mile from supermarket
# Value: 127.367744830262
#
# Field: Share of tract housing units receiving SNAP benefits count beyond 1/2 mile from supermarket
# Value: 0.17142361349968
#
# Field: Population count beyond 1 mile from supermarket
# Value: 483.429682502523
#
# Field: Share of tract population that are beyond 1 mile from supermarket
# Value: 0.222778655531117
#
# Field: Low income population count beyond 1 mile from supermarket
# Value: 145.14141792804
#
# Field: Share of tract population that are low income individuals beyond 1 mile from supermarket
# Value: 0.066885446049788
#
# Field: Kids population count beyond 1 mile from supermarket
# Value: 174.770469508133
#
# Field: Share of tract population that are kids beyond 1 mile from supermarket
# Value: 0.080539386870108
#
# Field: Seniors population count beyond 1 mile from supermarket
# Value: 50.9768215618096
#
# Field: Share of tract population that are seniors beyond 1 mile from supermarket
# Value: 0.023491622839544
#
# Field: White population count beyond 1 mile from supermarket
# Value: 128.16099537909
#
# Field: Share of tract population that are white beyond 1 mile from supermarket
# Value: 0.059060366534143
#
# Field: Black or African American population count beyond 1 mile from supermarket
# Value: 335.447720738127
#
# Field: Share of tract population that are Black or African American beyond 1 mile from supermarket
# Value: 0.154584203105128
#
# Field: Asian population count beyond 1 mile from supermarket
# Value: 1.59092694451101
#
# Field: Share of tract population that are Asian beyond 1 mile from supermarket
# Value: 0.000733146057378
#
# Field: Native Hawaiian or Other Pacific Islander population count beyond 1 mile from supermarket
# Value: 0.0
#
# Field: Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 1 mile from supermarket
# Value: 0.0
#
# Field: American Indian or Alaska Native population count beyond 1 mile from supermarket
# Value: 0.26351073384285
#
# Field: Share of tract population that are American Indian or Alaska Native beyond 1 mile from supermarket
# Value: 0.0001214335179
#
# Field: Other/Multiple race population count beyond 1 mile from supermarket
# Value: 17.9665312720462
#
# Field: Share of tract population that are Other/Multiple race beyond 1 mile from supermarket
# Value: 0.008279507498639
#
# Field: Hispanic or Latino ethnicity population count beyond 1 mile from supermarket
# Value: 11.1735897362232
#
# Field: Share of tract population that are of Hispanic or Latino ethnicity beyond 1 mile from supermarket
# Value: 0.005149119694112
#
# Field: Housing units without vehicle count beyond 1 mile from supermarket
# Value: 21.63833650382
#
# Field: Share of tract housing units that are without vehicle and beyond 1 mile from supermarket
# Value: 0.029122929345653
#
# Field: Housing units receiving SNAP benefits count beyond 1 mile from supermarket
# Value: 41.7009644495556
#
# Field: Share of tract housing units receiving SNAP benefits count beyond 1 mile from supermarket
# Value: 0.056125120389711
#
# Field: Population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Low income population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are low income individuals beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Kids population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are kids beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Seniors population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are seniors beyond 10 miles from supermarket
# Value: 0.0
#
# Field: White population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are white beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Black or African American population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are Black or African American beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Asian population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are Asian beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Native Hawaiian or Other Pacific Islander population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 10 miles from supermarket
# Value: 0.0
#
# Field: American Indian or Alaska Native population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are American Indian or Alaska Native beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Other/Multiple race population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are Other/Multiple race beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Hispanic or Latino ethnicity population count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are of Hispanic or Latino ethnicity beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Housing units without vehicle count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract housing units that are without vehicle and beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Housing units receiving SNAP benefits count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Share of tract housing units receiving SNAP benefits count beyond 10 miles from supermarket
# Value: 0.0
#
# Field: Population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Low income population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are low income individuals beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Kids population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are kids beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Seniors population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are seniors beyond 20 miles from supermarket
# Value: 0.0
#
# Field: White population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are white beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Black or African American population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are Black or African American beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Asian population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are Asian beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Native Hawaiian or Other Pacific Islander population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 20 miles from supermarket
# Value: 0.0
#
# Field: American Indian or Alaska Native population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are American Indian or Alaska Native beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Other/Multiple race population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are Other/Multiple race beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Hispanic or Latino ethnicity population count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract population that are of Hispanic or Latino ethnicity beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Housing units without vehicle count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract housing units that are without vehicle and beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Housing units receiving SNAP benefits count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Share of tract housing units receiving SNAP benefits count beyond 20 miles from supermarket
# Value: 0.0
#
# Field: Total count of low-income population in tract
# Value: 763.0
#
# Field: Total count of children age 0-17 in tract
# Value: 606.0
#
# Field: Total count of seniors age 65+ in tract
# Value: 214.0
#
# Field: Total count of White population in tract
# Value: 888.0
#
# Field: Total count of Black or African American population in tract
# Value: 1217.0
#
# Field: Total count of Asian population in tract
# Value: 5.0
#
# Field: Total count of Native Hawaiian and Other Pacific Islander population in tract
# Value: 0.0
#
# Field: Total count of American Indian and Alaska Native population in tract
# Value: 5.0
#
# Field: Total count of Other/Multiple race population in tract
# Value: 55.0
#
# Field: Total count of Hispanic or Latino population in tract
# Value: 75.0
#
# Field: Total count of housing units without a vehicle in tract
# Value: 87.0
#
# Field: Total count of housing units receiving SNAP benefits in tract
# Value: 202.0

# %% [markdown]
# -------------

# %% [markdown]
# #### Requirement III - Identify outliers and bad data.

# %% [markdown]
# Here, we use the code provided in "Data Wrangling with Python" to search for missing data and erroneous mismatching data.

# %%
# Create a list of lists using the list data for Sheet 1.
header_list = list_data(sheet1)

# Create an empty dictionary.
na_count = {}
for keys in results[0]:
    na_count[keys] = 0
# For loop to iterate over the key values in the results dictionary.
for key in results:
    '''
    Save the dictionary in the temp variable and then iterate over the key, value pairs as question/answer. Use and If statement
    to determing if there are any NA or null values. 
    '''
    temp = results[key]
    for item in temp:
        question = item
        answer = temp[item]
        if answer in ['NA','na','n/a','NULL']:
            na_count[question] += 1

# %%
na_count
# Out:
# {'Census tract number': 0,
#  'State name': 0,
#  'County name': 0,
#  'Flag for urban tract': 0,
#  'Population count from 2010 census': 0,
#  'Occupied housing unit count from 2010 census': 0,
#  'Flag for tract where >=67%': 0,
#  'Count of tract population residing in group quarters': 0,
#  'Percent of tract population residing in group quarters': 0,
#  'Flag for food desert when considering low accessibilty at 1 and 10 miles': 0,
#  'Flag for food desert when considering low accessibilty at 1/2 and 10 miles': 0,
#  'Flag for food desert when considering low accessibilty at 1 and 20 miles': 0,
#  'Flag for food desert when considering vehicle access or at 20 miles': 0,
#  'Flag for tract where >= 100 of households do not have a vehicle, and beyond 1/2 mile from supermarket': 0,
#  'Flag for low income tract': 0,
#  'Share of the tract population living with income at or below the Federal poverty thresholds for family size': 0,
#  'Tract median family income': 0,
#  'Flag for low access tract at 1 mile for urban areas or 10 miles for rural areas': 0,
#  'Flag for low access tract at 1/2 mile for urban areas or 10 miles for rural areas': 0,
#  'Flag for low access tract at 1 mile for urban areas or 20 miles for rural areas': 0,
#  'Flag for low access tract when considering 1/2 mile distance': 0,
#  'Flag for low access tract when considering 1 mile distance': 0,
#  'Flag for low access tract when considering 10 mile distance': 0,
#  'Flag for low access tract when considering 20 mile distance': 0,
#  'Flag for tract where >= 100 of households do not have a vehicle, and beyond 1/2 mile from supermarket; or >= 500 individuals are beyond 20 miles from supermarket ; or >= 33% of individuals are beyond 20 miles from supermarket': 0,
#  'Population count beyond 1 mile for urban areas or 10 miles for rural areas from supermarket': 0,
#  'Population count beyond 1/2 mile for urban areas or 10 miles for rural areas from supermarket': 0,
#  'Population count beyond 1 mile for urban areas or 20 miles for rural areas from supermarket': 0,
#  'Low income population count beyond 1 mile for urban areas or 10 miles for rural areas from supermarket': 0,
#  'Low income population count beyond 1/2 mile for urban areas or 10 miles for rural areas from supermarket': 0,
#  'Low income population count beyond 1 mile for urban areas or 20 miles for rural areas from supermarket': 0,
#  'Population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are beyond 1/2 mile from supermarket': 0,
#  'Low income population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are low income individuals beyond 1/2 mile from supermarket': 0,
#  'Kids population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are kids beyond 1/2 mile from supermarket': 0,
#  'Seniors population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are seniors beyond 1/2 mile from supermarket': 0,
#  'White population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are white beyond 1/2 mile from supermarket': 0,
#  'Black or African American population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are Black or African American beyond 1/2 mile from supermarket': 0,
#  'Asian population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are Asian beyond 1/2 mile from supermarket': 0,
#  'Native Hawaiian or Other Pacific Islander population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 1/2 mile from supermarket': 0,
#  'American Indian or Alaska Native population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are American Indian or Alaska Native beyond 1/2 mile from supermarket': 0,
#  'Other/Multiple race population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are Other/Multiple race beyond 1/2 mile from supermarket': 0,
#  'Hispanic or Latino ethnicity population count beyond 1/2 mile from supermarket': 0,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 1/2 mile from supermarket': 0,
#  'Housing units without vehicle count beyond 1/2 mile from supermarket': 0,
#  'Share of tract housing units that are without vehicle and beyond 1/2 mile from supermarket': 0,
#  'Housing units receiving SNAP benefits count beyond 1/2 mile from supermarket': 0,
#  'Share of tract housing units receiving SNAP benefits count beyond 1/2 mile from supermarket': 0,
#  'Population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are beyond 1 mile from supermarket': 0,
#  'Low income population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are low income individuals beyond 1 mile from supermarket': 0,
#  'Kids population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are kids beyond 1 mile from supermarket': 0,
#  'Seniors population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are seniors beyond 1 mile from supermarket': 0,
#  'White population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are white beyond 1 mile from supermarket': 0,
#  'Black or African American population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are Black or African American beyond 1 mile from supermarket': 0,
#  'Asian population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are Asian beyond 1 mile from supermarket': 0,
#  'Native Hawaiian or Other Pacific Islander population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 1 mile from supermarket': 0,
#  'American Indian or Alaska Native population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are American Indian or Alaska Native beyond 1 mile from supermarket': 0,
#  'Other/Multiple race population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are Other/Multiple race beyond 1 mile from supermarket': 0,
#  'Hispanic or Latino ethnicity population count beyond 1 mile from supermarket': 0,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 1 mile from supermarket': 0,
#  'Housing units without vehicle count beyond 1 mile from supermarket': 0,
#  'Share of tract housing units that are without vehicle and beyond 1 mile from supermarket': 0,
#  'Housing units receiving SNAP benefits count beyond 1 mile from supermarket': 0,
#  'Share of tract housing units receiving SNAP benefits count beyond 1 mile from supermarket': 0,
#  'Population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are beyond 10 miles from supermarket': 0,
#  'Low income population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are low income individuals beyond 10 miles from supermarket': 0,
#  'Kids population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are kids beyond 10 miles from supermarket': 0,
#  'Seniors population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are seniors beyond 10 miles from supermarket': 0,
#  'White population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are white beyond 10 miles from supermarket': 0,
#  'Black or African American population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are Black or African American beyond 10 miles from supermarket': 0,
#  'Asian population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are Asian beyond 10 miles from supermarket': 0,
#  'Native Hawaiian or Other Pacific Islander population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 10 miles from supermarket': 0,
#  'American Indian or Alaska Native population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are American Indian or Alaska Native beyond 10 miles from supermarket': 0,
#  'Other/Multiple race population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are Other/Multiple race beyond 10 miles from supermarket': 0,
#  'Hispanic or Latino ethnicity population count beyond 10 miles from supermarket': 0,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 10 miles from supermarket': 0,
#  'Housing units without vehicle count beyond 10 miles from supermarket': 0,
#  'Share of tract housing units that are without vehicle and beyond 10 miles from supermarket': 0,
#  'Housing units receiving SNAP benefits count beyond 10 miles from supermarket': 0,
#  'Share of tract housing units receiving SNAP benefits count beyond 10 miles from supermarket': 0,
#  'Population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are beyond 20 miles from supermarket': 0,
#  'Low income population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are low income individuals beyond 20 miles from supermarket': 0,
#  'Kids population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are kids beyond 20 miles from supermarket': 0,
#  'Seniors population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are seniors beyond 20 miles from supermarket': 0,
#  'White population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are white beyond 20 miles from supermarket': 0,
#  'Black or African American population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are Black or African American beyond 20 miles from supermarket': 0,
#  'Asian population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are Asian beyond 20 miles from supermarket': 0,
#  'Native Hawaiian or Other Pacific Islander population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 20 miles from supermarket': 0,
#  'American Indian or Alaska Native population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are American Indian or Alaska Native beyond 20 miles from supermarket': 0,
#  'Other/Multiple race population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are Other/Multiple race beyond 20 miles from supermarket': 0,
#  'Hispanic or Latino ethnicity population count beyond 20 miles from supermarket': 0,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 20 miles from supermarket': 0,
#  'Housing units without vehicle count beyond 20 miles from supermarket': 0,
#  'Share of tract housing units that are without vehicle and beyond 20 miles from supermarket': 0,
#  'Housing units receiving SNAP benefits count beyond 20 miles from supermarket': 0,
#  'Share of tract housing units receiving SNAP benefits count beyond 20 miles from supermarket': 0,
#  'Total count of low-income population in tract ': 0,
#  'Total count of children age 0-17 in tract ': 0,
#  'Total count of seniors age 65+ in tract ': 0,
#  'Total count of White population in tract ': 0,
#  'Total count of Black or African American population in tract ': 0,
#  'Total count of Asian population in tract ': 0,
#  'Total count of Native Hawaiian and Other Pacific Islander population in tract ': 0,
#  'Total count of American Indian and Alaska Native population in tract ': 0,
#  'Total count of Other/Multiple race population in tract ': 0,
#  'Total count of Hispanic or Latino population in tract ': 0,
#  'Total count of housing units without a vehicle in tract ': 0,
#  'Total count of housing units receiving SNAP benefits in tract ': 0}

# %% [markdown]
# Taking a look at the the resulting dictionary, we get 0 as total for NA or Null results across the all fields. However, how many 0 are there in the data?

# %%
zero_count = {}
# For loop to iterate over the key values in the results dictionary.
for keys in results[0]:
    zero_count[keys] = 0
    '''
    Save the dictionary in the temp variable and then iterate over the key, value pairs as question/answer. Use and If statement
    to determing if there are any NA or null values. 
    '''
for result in results:
    temp = results[result]
    for item in temp:
        answer = temp[item]
        if answer == 0:
            zero_count[item] += 1

# %%
zero_count
# Out:
# {'Census tract number': 0,
#  'State name': 0,
#  'County name': 7,
#  'Flag for urban tract': 17692,
#  'Population count from 2010 census': 333,
#  'Occupied housing unit count from 2010 census': 439,
#  'Flag for tract where >=67%': 72348,
#  'Count of tract population residing in group quarters': 27573,
#  'Percent of tract population residing in group quarters': 27573,
#  'Flag for food desert when considering low accessibilty at 1 and 10 miles': 63619,
#  'Flag for food desert when considering low accessibilty at 1/2 and 10 miles': 52308,
#  'Flag for food desert when considering low accessibilty at 1 and 20 miles': 64759,
#  'Flag for food desert when considering vehicle access or at 20 miles': 61995,
#  'Flag for tract where >= 100 of households do not have a vehicle, and beyond 1/2 mile from supermarket': 56550,
#  'Flag for low income tract': 41994,
#  'Share of the tract population living with income at or below the Federal poverty thresholds for family size': 780,
#  'Tract median family income': 838,
#  'Flag for low access tract at 1 mile for urban areas or 10 miles for rural areas': 45337,
#  'Flag for low access tract at 1/2 mile for urban areas or 10 miles for rural areas': 23139,
#  'Flag for low access tract at 1 mile for urban areas or 20 miles for rural areas': 48154,
#  'Flag for low access tract when considering 1/2 mile distance': 26344,
#  'Flag for low access tract when considering 1 mile distance': 48542,
#  'Flag for low access tract when considering 10 mile distance': 69659,
#  'Flag for low access tract when considering 20 mile distance': 72476,
#  'Flag for tract where >= 100 of households do not have a vehicle, and beyond 1/2 mile from supermarket; or >= 500 individuals are beyond 20 miles from supermarket ; or >= 33% of individuals are beyond 20 miles from supermarket': 56226,
#  'Population count beyond 1 mile for urban areas or 10 miles for rural areas from supermarket': 31608,
#  'Population count beyond 1/2 mile for urban areas or 10 miles for rural areas from supermarket': 15441,
#  'Population count beyond 1 mile for urban areas or 20 miles for rural areas from supermarket': 37394,
#  'Low income population count beyond 1 mile for urban areas or 10 miles for rural areas from supermarket': 31834,
#  'Low income population count beyond 1/2 mile for urban areas or 10 miles for rural areas from supermarket': 15707,
#  'Low income population count beyond 1 mile for urban areas or 20 miles for rural areas from supermarket': 37608,
#  'Population count beyond 1/2 mile from supermarket': 5171,
#  'Share of tract population that are beyond 1/2 mile from supermarket': 5171,
#  'Low income population count beyond 1/2 mile from supermarket': 5508,
#  'Share of tract population that are low income individuals beyond 1/2 mile from supermarket': 5508,
#  'Kids population count beyond 1/2 mile from supermarket': 5391,
#  'Share of tract population that are kids beyond 1/2 mile from supermarket': 5391,
#  'Seniors population count beyond 1/2 mile from supermarket': 5440,
#  'Share of tract population that are seniors beyond 1/2 mile from supermarket': 5440,
#  'White population count beyond 1/2 mile from supermarket': 5263,
#  'Share of tract population that are white beyond 1/2 mile from supermarket': 5263,
#  'Black or African American population count beyond 1/2 mile from supermarket': 5894,
#  'Share of tract population that are Black or African American beyond 1/2 mile from supermarket': 5894,
#  'Asian population count beyond 1/2 mile from supermarket': 7125,
#  'Share of tract population that are Asian beyond 1/2 mile from supermarket': 7125,
#  'Native Hawaiian or Other Pacific Islander population count beyond 1/2 mile from supermarket': 35181,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 1/2 mile from supermarket': 35181,
#  'American Indian or Alaska Native population count beyond 1/2 mile from supermarket': 8476,
#  'Share of tract population that are American Indian or Alaska Native beyond 1/2 mile from supermarket': 8476,
#  'Other/Multiple race population count beyond 1/2 mile from supermarket': 5454,
#  'Share of tract population that are Other/Multiple race beyond 1/2 mile from supermarket': 5454,
#  'Hispanic or Latino ethnicity population count beyond 1/2 mile from supermarket': 5453,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 1/2 mile from supermarket': 5453,
#  'Housing units without vehicle count beyond 1/2 mile from supermarket': 7956,
#  'Share of tract housing units that are without vehicle and beyond 1/2 mile from supermarket': 7956,
#  'Housing units receiving SNAP benefits count beyond 1/2 mile from supermarket': 7150,
#  'Share of tract housing units receiving SNAP benefits count beyond 1/2 mile from supermarket': 7150,
#  'Population count beyond 1 mile from supermarket': 21345,
#  'Share of tract population that are beyond 1 mile from supermarket': 21345,
#  'Low income population count beyond 1 mile from supermarket': 21641,
#  'Share of tract population that are low income individuals beyond 1 mile from supermarket': 21641,
#  'Kids population count beyond 1 mile from supermarket': 21728,
#  'Share of tract population that are kids beyond 1 mile from supermarket': 21728,
#  'Seniors population count beyond 1 mile from supermarket': 21768,
#  'Share of tract population that are seniors beyond 1 mile from supermarket': 21768,
#  'White population count beyond 1 mile from supermarket': 21480,
#  'Share of tract population that are white beyond 1 mile from supermarket': 21480,
#  'Black or African American population count beyond 1 mile from supermarket': 23347,
#  'Share of tract population that are Black or African American beyond 1 mile from supermarket': 23347,
#  'Asian population count beyond 1 mile from supermarket': 24800,
#  'Share of tract population that are Asian beyond 1 mile from supermarket': 24800,
#  'Native Hawaiian or Other Pacific Islander population count beyond 1 mile from supermarket': 49895,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 1 mile from supermarket': 49895,
#  'American Indian or Alaska Native population count beyond 1 mile from supermarket': 27504,
#  'Share of tract population that are American Indian or Alaska Native beyond 1 mile from supermarket': 27504,
#  'Other/Multiple race population count beyond 1 mile from supermarket': 22346,
#  'Share of tract population that are Other/Multiple race beyond 1 mile from supermarket': 22346,
#  'Hispanic or Latino ethnicity population count beyond 1 mile from supermarket': 22331,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 1 mile from supermarket': 22331,
#  'Housing units without vehicle count beyond 1 mile from supermarket': 25122,
#  'Share of tract housing units that are without vehicle and beyond 1 mile from supermarket': 25122,
#  'Housing units receiving SNAP benefits count beyond 1 mile from supermarket': 22911,
#  'Share of tract housing units receiving SNAP benefits count beyond 1 mile from supermarket': 22911,
#  'Population count beyond 10 miles from supermarket': 65478,
#  'Share of tract population that are beyond 10 miles from supermarket': 65478,
#  'Low income population count beyond 10 miles from supermarket': 65501,
#  'Share of tract population that are low income individuals beyond 10 miles from supermarket': 65501,
#  'Kids population count beyond 10 miles from supermarket': 65663,
#  'Share of tract population that are kids beyond 10 miles from supermarket': 65663,
#  'Seniors population count beyond 10 miles from supermarket': 65634,
#  'Share of tract population that are seniors beyond 10 miles from supermarket': 65634,
#  'White population count beyond 10 miles from supermarket': 65502,
#  'Share of tract population that are white beyond 10 miles from supermarket': 65502,
#  'Black or African American population count beyond 10 miles from supermarket': 68069,
#  'Share of tract population that are Black or African American beyond 10 miles from supermarket': 68069,
#  'Asian population count beyond 10 miles from supermarket': 68808,
#  'Share of tract population that are Asian beyond 10 miles from supermarket': 68808,
#  'Native Hawaiian or Other Pacific Islander population count beyond 10 miles from supermarket': 71688,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 10 miles from supermarket': 71688,
#  'American Indian or Alaska Native population count beyond 10 miles from supermarket': 68088,
#  'Share of tract population that are American Indian or Alaska Native beyond 10 miles from supermarket': 68088,
#  'Other/Multiple race population count beyond 10 miles from supermarket': 66596,
#  'Share of tract population that are Other/Multiple race beyond 10 miles from supermarket': 66596,
#  'Hispanic or Latino ethnicity population count beyond 10 miles from supermarket': 66841,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 10 miles from supermarket': 66841,
#  'Housing units without vehicle count beyond 10 miles from supermarket': 66216,
#  'Share of tract housing units that are without vehicle and beyond 10 miles from supermarket': 66216,
#  'Housing units receiving SNAP benefits count beyond 10 miles from supermarket': 65534,
#  'Share of tract housing units receiving SNAP benefits count beyond 10 miles from supermarket': 65534,
#  'Population count beyond 20 miles from supermarket': 71511,
#  'Share of tract population that are beyond 20 miles from supermarket': 71511,
#  'Low income population count beyond 20 miles from supermarket': 71521,
#  'Share of tract population that are low income individuals beyond 20 miles from supermarket': 71521,
#  'Kids population count beyond 20 miles from supermarket': 71649,
#  'Share of tract population that are kids beyond 20 miles from supermarket': 71649,
#  'Seniors population count beyond 20 miles from supermarket': 71602,
#  'Share of tract population that are seniors beyond 20 miles from supermarket': 71602,
#  'White population count beyond 20 miles from supermarket': 71533,
#  'Share of tract population that are white beyond 20 miles from supermarket': 71533,
#  'Black or African American population count beyond 20 miles from supermarket': 72372,
#  'Share of tract population that are Black or African American beyond 20 miles from supermarket': 72372,
#  'Asian population count beyond 20 miles from supermarket': 72318,
#  'Share of tract population that are Asian beyond 20 miles from supermarket': 72318,
#  'Native Hawaiian or Other Pacific Islander population count beyond 20 miles from supermarket': 72678,
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 20 miles from supermarket': 72678,
#  'American Indian or Alaska Native population count beyond 20 miles from supermarket': 72083,
#  'Share of tract population that are American Indian or Alaska Native beyond 20 miles from supermarket': 72083,
#  'Other/Multiple race population count beyond 20 miles from supermarket': 71862,
#  'Share of tract population that are Other/Multiple race beyond 20 miles from supermarket': 71862,
#  'Hispanic or Latino ethnicity population count beyond 20 miles from supermarket': 71880,
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 20 miles from supermarket': 71880,
#  'Housing units without vehicle count beyond 20 miles from supermarket': 71716,
#  'Share of tract housing units that are without vehicle and beyond 20 miles from supermarket': 71716,
#  'Housing units receiving SNAP benefits count beyond 20 miles from supermarket': 71535,
#  'Share of tract housing units receiving SNAP benefits count beyond 20 miles from supermarket': 71535,
#  'Total count of low-income population in tract ': 685,
#  'Total count of children age 0-17 in tract ': 477,
#  'Total count of seniors age 65+ in tract ': 520,
#  'Total count of White population in tract ': 362,
#  'Total count of Black or African American population in tract ': 757,
#  'Total count of Asian population in tract ': 1479,
#  'Total count of Native Hawaiian and Other Pacific Islander population in tract ': 27703,
#  'Total count of American Indian and Alaska Native population in tract ': 1828,
#  'Total count of Other/Multiple race population in tract ': 473,
#  'Total count of Hispanic or Latino population in tract ': 462,
#  'Total count of housing units without a vehicle in tract ': 2823,
#  'Total count of housing units receiving SNAP benefits in tract ': 2405}

# %% [markdown]
# We have quite a few fields that have 0's as the leading values. Some questions have over 70,000 observations with a value of 0. This is worth exploring in the future.

# %% [markdown]
# --------------------

# %% [markdown]
# Next, we explore potential data mismatch in terms of types within the same fields.

# %%
'''
Create the data_types dictionary by using the keys from the existing results dictionary and assign another dictionary with the other 
data types. 
'''

data_types = {}
for keys in results[0]:
    data_types[keys] = {'digit': 0, 'boolean': 0, 'empty': 0, 'date-time': 0, 'text': 0, 'unknown': 0}

'''
for loop to iterate over the results dictionary, save the dictionary in the temp variable. For loop iterates over the dictionary in 
the temp variable and saves the key, value pairs in the question and answer variables respectively. key variable is defaulted to 
unknown. If statement used to identify the correct value of key and then increment on the value.
'''
for key in results:
    temp = results[key]
    for item in temp:
        question = item
        answer = temp[item]
        key = 'unknown'
        if isinstance(answer, int) == True or isinstance(answer, float) == True:
            kt = 'digit'
        elif answer in ['Yes','No', 'True', 'False']:
            kt = 'boolean'
        elif answer.isspace():
            kt = 'empty'
        elif answer.find('/') > 0 or answer.find(':') > 0:
            kt = 'date-time'
        elif answer.isalpha():
            kt = 'text'
        data_types[question][kt] +=1

# %%
data_types
# Out:
# {'Census tract number': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'State name': {'digit': 12335,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 60529,
#   'unknown': 0},
#  'County name': {'digit': 750,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 72114,
#   'unknown': 0},
#  'Flag for urban tract': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Population count from 2010 census': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Occupied housing unit count from 2010 census': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for tract where >=67%': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Count of tract population residing in group quarters': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Percent of tract population residing in group quarters': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for food desert when considering low accessibilty at 1 and 10 miles': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for food desert when considering low accessibilty at 1/2 and 10 miles': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for food desert when considering low accessibilty at 1 and 20 miles': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for food desert when considering vehicle access or at 20 miles': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for tract where >= 100 of households do not have a vehicle, and beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for low income tract': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of the tract population living with income at or below the Federal poverty thresholds for family size': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Tract median family income': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for low access tract at 1 mile for urban areas or 10 miles for rural areas': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for low access tract at 1/2 mile for urban areas or 10 miles for rural areas': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for low access tract at 1 mile for urban areas or 20 miles for rural areas': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for low access tract when considering 1/2 mile distance': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for low access tract when considering 1 mile distance': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for low access tract when considering 10 mile distance': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for low access tract when considering 20 mile distance': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Flag for tract where >= 100 of households do not have a vehicle, and beyond 1/2 mile from supermarket; or >= 500 individuals are beyond 20 miles from supermarket ; or >= 33% of individuals are beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Population count beyond 1 mile for urban areas or 10 miles for rural areas from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Population count beyond 1/2 mile for urban areas or 10 miles for rural areas from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Population count beyond 1 mile for urban areas or 20 miles for rural areas from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Low income population count beyond 1 mile for urban areas or 10 miles for rural areas from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Low income population count beyond 1/2 mile for urban areas or 10 miles for rural areas from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Low income population count beyond 1 mile for urban areas or 20 miles for rural areas from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Low income population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are low income individuals beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Kids population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are kids beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Seniors population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are seniors beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'White population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are white beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Black or African American population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Black or African American beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Asian population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Asian beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Native Hawaiian or Other Pacific Islander population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'American Indian or Alaska Native population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are American Indian or Alaska Native beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Other/Multiple race population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Other/Multiple race beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Hispanic or Latino ethnicity population count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Housing units without vehicle count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract housing units that are without vehicle and beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Housing units receiving SNAP benefits count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract housing units receiving SNAP benefits count beyond 1/2 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Low income population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are low income individuals beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Kids population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are kids beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Seniors population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are seniors beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'White population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are white beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Black or African American population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Black or African American beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Asian population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Asian beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Native Hawaiian or Other Pacific Islander population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'American Indian or Alaska Native population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are American Indian or Alaska Native beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Other/Multiple race population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Other/Multiple race beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Hispanic or Latino ethnicity population count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Housing units without vehicle count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract housing units that are without vehicle and beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Housing units receiving SNAP benefits count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract housing units receiving SNAP benefits count beyond 1 mile from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Low income population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are low income individuals beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Kids population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are kids beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Seniors population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are seniors beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'White population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are white beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Black or African American population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Black or African American beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Asian population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Asian beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Native Hawaiian or Other Pacific Islander population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'American Indian or Alaska Native population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are American Indian or Alaska Native beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Other/Multiple race population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Other/Multiple race beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Hispanic or Latino ethnicity population count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Housing units without vehicle count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract housing units that are without vehicle and beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Housing units receiving SNAP benefits count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract housing units receiving SNAP benefits count beyond 10 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Low income population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are low income individuals beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Kids population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are kids beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Seniors population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are seniors beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'White population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are white beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Black or African American population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Black or African American beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Asian population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Asian beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Native Hawaiian or Other Pacific Islander population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Native Hawaiian or Other Pacific Islander beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'American Indian or Alaska Native population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are American Indian or Alaska Native beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Other/Multiple race population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are Other/Multiple race beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Hispanic or Latino ethnicity population count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract population that are of Hispanic or Latino ethnicity beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Housing units without vehicle count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract housing units that are without vehicle and beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Housing units receiving SNAP benefits count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Share of tract housing units receiving SNAP benefits count beyond 20 miles from supermarket': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of low-income population in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of children age 0-17 in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of seniors age 65+ in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of White population in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of Black or African American population in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of Asian population in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of Native Hawaiian and Other Pacific Islander population in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of American Indian and Alaska Native population in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of Other/Multiple race population in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of Hispanic or Latino population in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of housing units without a vehicle in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0},
#  'Total count of housing units receiving SNAP benefits in tract ': {'digit': 72864,
#   'boolean': 0,
#   'empty': 0,
#   'date-time': 0,
#   'text': 0,
#   'unknown': 0}}

# %% [markdown]
# The dictionary reveals that the data set is mostly comprised of numbers and text. Of interest is the fact that the State Name and County Name fields actually have numbers in them.

# %% [markdown]
# ----------------------------

# %% [markdown]
# #### Requirement IV - Find Duplicates

# %% [markdown]
# For this part, we are going to use list generators with set() to weed out duplicates.

# %%
set_of_lines = set([results[result]['Census tract number'] for result in results])

# %%
len(set_of_lines)
# Out:
# 72864

# %% [markdown]
# This is the exact number of records. Next, we create unique identifiers using the census tract number, state name and county name.

# %%
'''
Create a unique_ids list. For loop to iterate over the results dictionary and get the Census tract number, state name and County name.
create a concatentanted string, store it in the unique variable and append it to the unique_ids list. Use set to potentially de-dupe 
the data. In this case it's not going to do much. Still, good practice for a next de-dupe efforts. 
'''
unique_ids = list()
for result in results:
    ctn = results[result]['Census tract number']
    sn = results[result]['State name']
    cn = results[result]['County name']
    unique = f'{ctn}-{sn}-{cn}'
    unique_ids.append(unique)
unique_set = set(unique_ids)

# %%
len(unique_set)
# Out:
# 72864

# %%
len(unique_ids)
# Out:
# 72864

# %% [markdown]
# While the census tract number is distinct enough to make all of the created identifiers distinct from one another, this was still a good exercise in how to create sets for potential de-duplication efforts down the road.

# %% [markdown]
# --------------

# %% [markdown]
# #### Requirement V - Conduct Fuzzy Matching

# %% [markdown]
# For this segment, we start by importing the _fuzzywuzzy_ module

# %%
from fuzzywuzzy import fuzz
# Out:
# /Users/ambrosemmalagon-cordero/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# With two text fields - State Name and County Name - One apparent use that comes to mind is to narrow down potential state/county combinations. For example, there is _Dunn_ county in one of Dakota's. However, we don't necessarily know which one of the Dakota's. We are also not quite sure of the spelling of Dunn - Does it have 1 or 2 n's at the end. Let's look at the following script:

# %%
test_string = 'dakota'
test_string2 = 'dun'
print('Fuzzy Match Search Results > 60% Match Rate\n')
'''
Iterate over results. Using an if statement where we will print the State Name and County Name only if the token sort ratio of 
test_string and test_string2 is higher than 60.
'''
for result in results:
    if fuzz.token_sort_ratio(test_string, results[result]['State name']) > 60 and fuzz.token_sort_ratio(test_string2, results[result]['County name']) > 60:
        st = results[result]['State name']
        cn = results[result]['County name']
        print(f'State: {st}')
        print(f'County: {cn}\n')
# Out:
# Fuzzy Match Search Results > 60% Match Rate
#
# State: North Dakota
# County: Dunn

# %% [markdown]
# By using the token_sort_ratio method from _fuzz_, we got North Dakota as the State and the County of Dunn (spelled with 2 n's at the end)

# %% [markdown]
# -----------------------

# %% [markdown]
# #### Conclusion and Final Thoughts.

# %% [markdown]
# The steps/requirements detailed in this project have provided some insights in regards to this data set:
#
# * With the exception of two fields, this data set is comprised of mostly numerical data. The State name and County name fields are, for the most part, comprised of text with some numerical data.
#
# * Our search for missing data (NA or null) yielded 0 results. However there several fields comprised solely of 0. We would need to delve further to understand what these truly mean: either these were truly captured values or if they represent missing values.
#
# * We can use fuzzy string matching to narrow down our search results.
#
# Next Steps - some Exploratory Data Analysis is in order.
